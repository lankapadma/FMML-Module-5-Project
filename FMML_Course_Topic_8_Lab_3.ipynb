# %% [markdown]
# <a href="https://colab.research.google.com/github/lankapadma/FMML-Module-5-Project/blob/main/FMML_Course_Topic_8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# Lab by V Vijay Vignesh
#
# vijay.vignesh@research.iiit.ac.in

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2024-03-26 15:13:15--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   135MB/s    in 0.5s
#
# 2024-03-26 15:13:16 (135 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False),
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split()
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 19168   1304.1522v1  Measures of uncertainty and divergence are int...    cs
# 4709    1401.3871v1  Markovian processes have long been used to mod...    cs
# 38477  cs/0211005v1  Although speech and gesture recognition has be...    cs
# 21584   1105.2493v6  We define and discuss the first sparse coding ...  stat
# 9011   1702.00564v2  We present a case-study demonstrating the usef...  stat
# ...             ...                                                ...   ...
# 27279  1703.01229v1  Deep neural networks are playing an important ...    cs
# 39659  1611.08280v4  This paper presents a regularized regression m...  stat
# 40637   1109.5664v4  We study feature selection for $k$-means clust...    cs
# 32031   1210.0699v1  We introduce semi-supervised data classificati...    cs
# 7845   1803.07879v1  A large fraction of the electronic health reco...  stat
#
#                                                    title  year  \
# 19168  Maximum Uncertainty Procedures for Interval-Va...  2013
# 4709   Non-Deterministic Policies in Markovian Decisi...  2014
# 38477  Prosody Based Co-analysis for Continuous Recog...  2002
# 21584  Closed-form EM for Sparse Coding and its Appli...  2011
# 9011   Modelling dependency completion in sentence co...  2017
# ...                                                  ...   ...
# 27279  Deep Collaborative Learning for Visual Recogni...  2017
# 39659  Two-Level Structural Sparsity Regularization f...  2016
# 40637  Deterministic Feature Selection for $k$-means ...  2011
# 32031  TV-SVM: Total Variation Support Vector Machine...  2012
# 7845   An Unsupervised Multivariate Time Series Kerne...  2018
#
#                                                 keywords
# 19168  [uncertainty, divergence, introduced, probabil...
# 4709   [markovian, processes, stochastic, environment...
# 38477  [recognition, extensively, successful, combini...
# 21584  [algorithm, continuous, variables, underlying,...
# 9011   [demonstrating, usefulness, hierarchical, mode...
# ...                                                  ...
# 27279  [important, recognition, represent, convolutio...
# 39659  [regularized, regression, structural, individu...
# 40637  [selection, clustering, literature, empirical,...
# 32031  [introduce, supervised, classification, algori...
# 7845   [electronic, measurements, collected, importan...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 19168    [uncertainty, divergence, introduced, probabil...
# 4709     [markovian, processes, stochastic, environment...
# 38477    [recognition, extensively, successful, combini...
# 21584    [algorithm, continuous, variables, underlying,...
# 9011     [demonstrating, usefulness, hierarchical, mode...
#                                ...
# 6830     [memorization, connections, generalization, ad...
# 17922    [clustering, discovering, structure, clusterin...
# 5616     [generalization, generalization, convergence, ...
# 19257    [describes, heuristic, computing, probability,...
# 31182    [detection, attracting, applications, challeng...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]),
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8851 words.
# Out of those 4556 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="a39c5a3f-df09-4893-8d30-7311315d74b6" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a39c5a3f-df09-4893-8d30-7311315d74b6")) {                    Plotly.newPlot(                        "a39c5a3f-df09-4893-8d30-7311315d74b6",                        [{"x":["projections","mathematical","probability","presented","technique","distributions","divergence","procedure","uncertainty","inference","procedures","developed","reconstruction","properties","desirable","introduced","reinforcement","navigation","markovian","synthetic","flexibility","solutions","outperform","sequential","selection","deterministic","environments","construct","algorithms","constraining","conventional","processes","introduces","stochastic","concerning","guidelines","framework","prescriptive","experiment","decisions","successful","frameworks","automatic","subsequently","motivated","extensively","articulation","inherited","formulations","broadcast","cooccurrence","combining","complexity","collected","semantically","recognition","improving","formulation","phenomenon","processing","demonstrated","prominent","disambiguating","occurrence","integration","detecting","continuous","particular","multimodal","generative","probabilistic","efficiently","resulting","experiments","directions","maximization","underlying","likelihood","posterior","artificial","variables","resources","comprised","benchmarks","algorithm","separation","competitive","computational","dimensions","equations","application","realistic","parameters","generalizing","exponentially","numerical","potentially","investigating","retrievals","usefulness","retrieval","resolution","represents","linguistic","modelling","hierarchical","implement","demonstrating","completion","distribution","comprehension","alternative","dependency","dependent","cognitive","independent","involving","promoting","constraints","alternates","achieving","correlation","different","compounds","sublinear","effectiveness","alternating","converges","regularization","judiciously","multilingual","structure","substantial","scalability","important","considered","simulations","principal","optimally","decomposition","dimensional","embedding","component","pertinent","generalized","multiview","components","approaches","constrained","regularized","subproblem","optimization","structural","negativity","canonical","integrate","information","incorporating","distortion","robustness","adversarially","competition","constraint","discourages","attacking","demonstrate","experimental","adversarial","transferable","optimized","generating","performed","stepsizes","numerically","convergence","minimization","stationary","coordinate","guaranteed","furthermore","bottleneck","successive","subgradient","convergent","approximation","nonconvex","theoretical","threshold","statistical","intelligence","ensembles","classification","discriminating","operating","calculation","interpretations","equivalence","assessment","knowledge","calculate"],"y":[15,67,155,177,233,111,17,129,92,217,44,189,78,228,31,127,116,32,5,160,36,147,105,78,160,42,86,91,624,5,92,99,73,138,15,16,531,3,71,65,71,29,177,31,73,45,3,2,23,11,3,114,245,67,33,367,96,79,26,289,112,12,5,35,60,88,112,277,33,134,176,150,154,577,54,33,129,50,37,156,129,54,10,103,800,30,114,282,47,23,251,54,239,12,24,82,43,10,1,26,104,99,51,63,49,98,76,32,39,207,13,82,46,78,54,111,55,3,150,7,79,81,741,0,7,218,21,22,96,2,24,334,44,42,359,121,46,39,12,79,176,106,129,1,74,5,109,442,55,48,0,309,61,2,22,44,660,54,24,101,2,31,96,0,4,552,399,106,5,57,107,133,2,14,112,64,24,30,27,169,17,13,4,7,124,8,166,32,145,91,13,528,9,17,22,18,25,50,335,20],"type":"bar"},{"x":["projections","mathematical","probability","presented","technique","distribut ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4556,), (4556, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7691666666666667

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(0, 255, 0, 0.3);'>Improving</span> <span style='background-color:rgba(0, 255, 0, 0.32);'>precision</span> <span style=''>and</span> <span style=''>recall</span> <span style=''>of</span> <span style=''>face</span> <span style='background-color:rgba(0, 255, 0, 0.620309050772627);'>recognition</span> <span style=''>in</span> <span style=''>SIPP</span> <span style=''>with</span> <span style='background-color:rgba(0, 255, 0, 0.33668341708542715);'>combination</span> <span style=''>of</span> <span style=''>modified</span> <span style=''>mean</span> <span style=''>search</span> <span style=''>and</span> <span style=''>LSH</span> <br/><br/><span style=''>Although</span> <span style=''>face</span> <span style='background-color:rgba(0, 255, 0, 0.620309050772627);'>recognition</span> <span style=''>has</span> <span style=''>been</span> <span style=''>improved</span> <span style=''>much</span> <span style=''>as</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.4917127071823204);'>development</span> <span style=''>of</span> <span style=''>Deep</span> <span style=''>Neural</span> <span style=''>Networks</span> <span style=''>SIPP(Single</span> <span style=''>Image</span> <span style=''>Per</span> <span style=''>Person)</span> <span style=''>problem</span> <span style=''>in</span> <span style=''>face</span> <span style='background-color:rgba(0, 255, 0, 0.620309050772627);'>recognition</span> <span style=''>has</span> <span style=''>not</span> <span style=''>been</span> <span style=''>better</span> <span style=''>solved</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>especially</span> <span style=''>in</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>practical</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>applications</span> <span style=''>where</span> <span style='background-color:rgba(0, 255, 0, 0.6097560975609756);'>searching</span> <span style=''>over</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>complicated</span> <span style=''>database</span> <span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.33668341708542715);'>combination</span> <span style=''>of</span> <span style=''>modified</span> <span style=''>mean</span> <span style=''>search</span> <span style=''>and</span> <span style=''>LSH</span> <span style=''>method</span> <span style=''>would</span> <span style=''>be</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>introduced</span> <span style=''>orderly</span> <span style=''>to</span> <span style=''>improve</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.32);'>precision</span> <span style=''>and</span> <span style=''>recall</span> <span style=''>of</span> <span style=''>SIPP</span> <span style=''>face</span> <span style='background-color:rgba(0, 255, 0, 0.620309050772627);'>recognition</span> <span style=''>without</span> <span style=''>retrain</span> <span style=''>of</span> <span style=''>the</span> <span style=''>DNN</span> <span style=''>model</span> <span style=''>First</span> <span style=''>a</span> <span style=''>modified</span> <span style=''>SVD</span> <span style=''>based</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>augmentation</span> <span style=''>method</span> <span style=''>would</span> <span style=''>be</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>introduced</span> <span style=''>to</span> <span style=''>get</span> <span style=''>more</span> <span style=''>intra</span> <span style=''>class</span> <span style='background-color:rgba(0, 255, 0, 0.39999999999999997);'>variations</span> <span style=''>even</span> <span style=''>for</span> <span style=''>person</span> <span style=''>with</span> <span style=''>only</span> <span style=''>one</span> <span style=''>image</span> <span style=''>Second</span> <span style=''>an</span> <span style ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Learning</span> <span style=''>From</span> <span style=''>Non</span> <span style=''>iid</span> <span style=''>Data</span> <span style=''>Fast</span> <span style=''>Rates</span> <span style=''>for</span> <span style=''>the</span> <span style=''>One</span> <span style=''>vs</span> <span style=''>All</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Multiclass</span> <span style=''>Plug</span> <span style=''>in</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Classifiers</span> <br/><br/><span style=''>We</span> <span style=''>prove</span> <span style=''>new</span> <span style=''>fast</span> <span style=''>learning</span> <span style=''>rates</span> <span style=''>for</span> <span style=''>the</span> <span style=''>one</span> <span style=''>vs</span> <span style=''>all</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>multiclass</span> <span style=''>plug</span> <span style=''>in</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>classifiers</span> <span style=''>trained</span> <span style=''>either</span> <span style=''>from</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>exponentially</span> <span style=''>strongly</span> <span style=''>mixing</span> <span style=''>data</span> <span style=''>or</span> <span style=''>from</span> <span style=''>data</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>generated</span> <span style=''>by</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>converging</span> <span style=''>drifting</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>distribution</span> <span style=''>These</span> <span style=''>are</span> <span style=''>two</span> <span style=''>typical</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>scenarios</span> <span style=''>where</span> <span style=''>training</span> <span style=''>data</span> <span style=''>are</span> <span style=''>not</span> <span style=''>iid</span> <span style=''>The</span> <span style=''>learning</span> <span style=''>rates</span> <span style=''>are</span> <span style=''>obtained</span> <span style=''>under</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>multiclass</span> <span style=''>version</span> <span style=''>of</span> <span style=''>Tsybakovs</span> <span style=''>margin</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>assumption</span> <span style=''>a</span> <span style=''>type</span> <span style=''>of</span> <span style=''>low</span> <span style=''>noise</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>assumption</span> <span style=''>and</span> <span style=''>do</span> <span style=''>not</span> <span style=''>depend</span> <span style=''>on</span> <span style=''>the</span> <span style=''>number</span> <span style=''>of</span> <span style=''>classes</span> <span style=''>Our</span> <span style=''>results</span> <span style=''>are</span> <span style=''>general</span> <span style=''>and</span> <span style=''>include</span> <span style=''>a</span> <span style=''>previous</span> <span style=''>result</span> <span style=''>for</span> <span style=''>binary</span> <span style=''>class</span> <span style=''>plug</span> <span style=''>in</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>classifiers</span> <span style=''>with</span> <span style=''>iid</span> <span style=''>data</span> <span style=''>as</span> <span style=''>a</span> <span style=''>special</span> <span style=''>case</span> <span style=''>In</span> <span style=''>contrast</span> <span style=''>to</span> <span style=''>previous</span> <span style=''>works</span> <span style=''>for</span> <span style=''>least</span> <span style=''>squares</span> <span style=''>SVMs</span> <span style=''>under</span> <span style=''>the</span> <span style=''>binary</span> <span style=''>class</span> <span style=''>setting</span> <span style=''>our</span> <span style=''>results</span> <span style=''>retain</span> <span ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(255, 0, 0, 0.746031746031746);'>Nonparametric</span> <span style=''>Link</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Prediction</span> <span style=''>in</span> <span style=''>Dynamic</span> <span style=''>Networks</span> <br/><br/><span style=''>We</span> <span style=''>propose</span> <span style=''>a</span> <span style=''>non</span> <span style='background-color:rgba(255, 0, 0, 0.48148148148148145);'>parametric</span> <span style=''>link</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>prediction</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithm</span> <span style=''>for</span> <span style=''>a</span> <span style=''>sequence</span> <span style=''>of</span> <span style=''>graph</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>snapshots</span> <span style=''>over</span> <span style=''>time</span> <span style=''>The</span> <span style=''>model</span> <span style=''>predicts</span> <span style=''>links</span> <span style=''>based</span> <span style=''>on</span> <span style=''>the</span> <span style=''>features</span> <span style=''>of</span> <span style=''>its</span> <span style='background-color:rgba(0, 255, 0, 0.33333333333333326);'>endpoints</span> <span style=''>as</span> <span style=''>well</span> <span style=''>as</span> <span style=''>those</span> <span style=''>of</span> <span style=''>the</span> <span style=''>local</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>neighborhood</span> <span style=''>around</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.33333333333333326);'>endpoints</span> <span style=''>This</span> <span style=''>allows</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3243967828418231);'>different</span> <span style=''>types</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>neighborhoods</span> <span style=''>in</span> <span style=''>a</span> <span style=''>graph</span> <span style=''>each</span> <span style=''>with</span> <span style=''>its</span> <span style=''>own</span> <span style=''>dynamics</span> <span style=''>(eg</span> <span style=''>growing</span> <span style=''>or</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>shrinking</span> <span style=''>communities)</span> <span style=''>We</span> <span style=''>prove</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>consistency</span> <span style=''>of</span> <span style=''>our</span> <span style='background-color:rgba(255, 0, 0, 0.7215189873417721);'>estimator</span> <span style=''>and</span> <span style=''>give</span> <span style=''>a</span> <span style=''>fast</span> <span style='background-color:rgba(0, 255, 0, 0.3233830845771144);'>implementation</span> <span style=''>based</span> <span style=''>on</span> <span style=''>locality</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>sensitive</span> <span style=''>hashing</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Experiments</span> <span style=''>with</span> <span style='background-color:rgba(255, 0, 0, 0.39215686274509814);'>simulated</span> <span style=''>as</span> <span style=''>well</span> <span style=''>as</span> <span style=''>five</span> <span style=''>real</span> <span style=''>world</span> <span style=''>dynamic</span> <span style=''>graphs</span> <span style=''>show</span> <span style=''>that</span> <span style=''>we</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>outperform</span> <span style=''>the</span> <span style=''>state</span> <span style=''>of</span> <span style=''>the</span> <span style=''>art</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>especially</span> <span style=''>when</span> <span style=''>sharp</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>fluctuations</span> <span style=''>or</span> <span style=''>non</span> <span style='background-color:rgba(255, 0, 0, 0.7 ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>End</span> <span style=''>to</span> <span style=''>End</span> <span style=''>Learning</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Structured</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Prediction</span> <span style=''>Energy</span> <span style=''>Networks</span> <br/><br/><span style='background-color:rgba(0, 255, 0, 0.3);'>Structured</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Prediction</span> <span style=''>Energy</span> <span style=''>Networks</span> <span style=''>(SPENs)</span> <span style=''>are</span> <span style=''>a</span> <span style=''>simple</span> <span style=''>yet</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>expressive</span> <span style=''>family</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>structured</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>prediction</span> <span style=''>models</span> <span style=''>(Belanger</span> <span style=''>and</span> <span style=''>McCallum</span> <span style=''>2016)</span> <span style=''>An</span> <span style=''>energy</span> <span style=''>function</span> <span style=''>over</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>candidate</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>structured</span> <span style=''>outputs</span> <span style=''>is</span> <span style=''>given</span> <span style=''>by</span> <span style=''>a</span> <span style=''>deep</span> <span style=''>network</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>predictions</span> <span style=''>are</span> <span style=''>formed</span> <span style=''>by</span> <span style=''>gradient</span> <span style=''>based</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>optimization</span> <span style=''>This</span> <span style=''>paper</span> <span style=''>presents</span> <span style=''>end</span> <span style=''>to</span> <span style=''>end</span> <span style=''>learning</span> <span style=''>for</span> <span style=''>SPENs</span> <span style=''>where</span> <span style=''>the</span> <span style=''>energy</span> <span style=''>function</span> <span style=''>is</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>discriminatively</span> <span style=''>trained</span> <span style=''>by</span> <span style=''>back</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>propagating</span> <span style=''>through</span> <span style=''>gradient</span> <span style=''>based</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>prediction</span> <span style=''>In</span> <span style=''>our</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>experience</span> <span style=''>the</span> <span style=''>approach</span> <span style=''>is</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>substantially</span> <span style=''>more</span> <span style=''>accurate</span> <span style=''>than</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>structured</span> <span style=''>SVM</span> <span style=''>method</span> <span style=''>of</span> <span style=''>Belanger</span> <span style=''>and</span> <span style=''>McCallum</span> <span style=''>(2016)</span> <span style=''>as</span> <span style=''>it</span> <span style=''>allows</span> <span style=''>us</span> <span style=''>to</span> <span style=''>use</span> <span style=''>more</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>sophisticated</span> <span style=''>non</span> <span style=''>convex</span> <span style=''>energies</span> <span style=''>We</span> <span style=''>provide</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>collection</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>techniques</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>improving</span> <span style=''>the</span> <span s ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	representation (0.13373536715147216)
# 	knowledge (0.11883646683221)
# 	experimental (0.14153955303299043)
# 	segmentation (0.07272082298687478)
# 	information (0.23412557644554807)
# 	architecture (0.0957786449095424)
# 	detection (0.1248669741042923)
# 	different (0.2628591699184108)
# 	recognition (0.1301880099326002)
# 	convolutional (0.13550904576090814)
#
# Some Statistics words are:
# 	distributions (0.12115093387178193)
# 	convergence (0.12216052498738011)
# 	stochastic (0.1347804139323574)
# 	theoretical (0.16658253407370016)
# 	distribution (0.18172640080767288)
# 	statistical (0.16002019182231197)
# 	algorithm (0.397778899545684)
# 	inference (0.19434628975265017)
# 	regression (0.17768803634528016)
# 	dimensional (0.19687026754164563)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]),
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="eb71ef6f-28ca-4bba-b487-ac00fb1edbee" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("eb71ef6f-28ca-4bba-b487-ac00fb1edbee")) {                    Plotly.newPlot(                        "eb71ef6f-28ca-4bba-b487-ac00fb1edbee",                        [{"x":["projections","mathematical","probability","presented","technique","distributions","divergence","procedure","uncertainty","inference","procedures","developed","reconstruction","properties","desirable","introduced","reinforcement","navigation","markovian","synthetic","flexibility","solutions","outperform","sequential","selection","deterministic","environments","construct","algorithms","constraining","conventional","processes","introduces","stochastic","concerning","guidelines","framework","prescriptive","experiment","decisions","successful","frameworks","automatic","subsequently","motivated","extensively","articulation","inherited","formulations","broadcast","cooccurrence","combining","complexity","collected","semantically","recognition","improving","formulation","phenomenon","processing","demonstrated","prominent","disambiguating","occurrence","integration","detecting","continuous","particular","multimodal","generative","probabilistic","efficiently","resulting","experiments","directions","maximization","underlying","likelihood","posterior","artificial","variables","resources","comprised","benchmarks","algorithm","separation","competitive","computational","dimensions","equations","application","realistic","parameters","generalizing","exponentially","numerical","potentially","investigating","retrievals","usefulness","retrieval","resolution","represents","linguistic","modelling","hierarchical","implement","demonstrating","completion","distribution","comprehension","alternative","dependency","dependent","cognitive","independent","involving","promoting","constraints","alternates","achieving","correlation","different","compounds","sublinear","effectiveness","alternating","converges","regularization","judiciously","multilingual","structure","substantial","scalability","important","considered","simulations","principal","optimally","decomposition","dimensional","embedding","component","pertinent","generalized","multiview","components","approaches","constrained","regularized","subproblem","optimization","structural","negativity","canonical","integrate","information","incorporating","distortion","robustness","adversarially","competition","constraint","discourages","attacking","demonstrate","experimental","adversarial","transferable","optimized","generating","performed","stepsizes","numerically","convergence","minimization","stationary","coordinate","guaranteed","furthermore","bottleneck","successive","subgradient","convergent","approximation","nonconvex","theoretical","threshold","statistical","intelligence","ensembles","classification","discriminating","operating","calculation","interpretations","equivalence","assessment","knowledge","calculate","practical","classifiers","validation","simplifies","thoroughly","averaging","kolmogorov","integrates","geometrically","performance","satisfactory","character","extracting","invariance","including","available","convolutional","handwritten","systematically","characters","improvement","translation","recognizers","evaluated","technology","convolution","ambiguous","applications","distortions","advantage","effectively","stability","consequence","regularity","specifically","certificates","theoretic","explicitly","simulated","verification","considers","assumptions","additional","guarantees","formulate","challenge","submodular","intractable","encounters","straightforward","advertisements","recommend","computationally","formulated","iteration"," ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	compounds
# 	subproblem
# 	discourages
# 	subsampling
# 	dimensionalities
# 	integrative
# 	breaching
# 	transferability
# 	telescope
# 	metastable
# 	repertoire
# 	repertoires
# 	semiparametric
# 	asymmetry
# 	instabilities
# 	combustion
# 	circularity
# 	hypernetwork
# 	hypernetworks
# 	intracellular
# Some words which never appear in Statistics papers:
# 	navigation
# 	prescriptive
# 	articulation
# 	inherited
# 	disambiguating
# 	recognizers
# 	strengthen
# 	playground
# 	dissertation
# 	disjunctive
# 	propositional
# 	paragraphs
# 	unconditioned
# 	unitarily
# 	deductive
# 	confirmation
# 	interpreter
# 	storytelling
# 	deblurring
# 	conversational

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.053808098699078e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7208333333333333
